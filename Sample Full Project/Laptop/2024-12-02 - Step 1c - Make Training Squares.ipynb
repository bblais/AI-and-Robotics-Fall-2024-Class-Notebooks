# %%
# %matplotlib inline
from pylab import *
import cv2
from glob import glob
from image_defs import *
import os

# %%
board_picture_folder='images/2024-11-21 - training board images'
square_images_folder='images/2024-11-21 - training squares'
image_to_use_for_corners="images/2024-11-21 - training board images/test0.jpg"

from corners import *

# %%
board_filenames=sorted(glob(board_picture_folder+"/*.jpg"))
print(len(board_filenames))
# Out:
# 10

# %% [markdown]
# ## Look at all the boards

# %%
count=1
figure(figsize=(15,10))
for filename in board_filenames:
    subplot(3,4,count)

    image=imread(filename)
    #image=image[:,300:1400]  # truncate if you need to
    
    imshow(image)

    
    base,name=os.path.split(filename)
    title(name)
    print(name)
    count+=1
# Out:
# test0.jpg
# test1.jpg
# test10.jpg
# test2.jpg
# test3.jpg
# test4.jpg
# test5.jpg
# test6.jpg
# test7.jpg
# test8.jpg

# %%
board_states={
    'test10.jpg': '0000/0000/0000/0000',
     'test6.jpg': '1111/1111/1111/1111',
     'test7.jpg': '1111/1111/1111/1111',
     'test5.jpg': '1111/1111/1111/1111',
     'test4.jpg': '0000/0000/0000/0000',
     'test0.jpg': '2222/2222/2222/2222',
     'test1.jpg': '2222/2222/2222/2222',
     'test3.jpg': '0202/2020/0202/0202',
     'test2.jpg': '2222/2222/2222/2222',
     'test8.jpg': '1101/1011/0000/1111'
}

# %%
from Game import *

# %%
count=0
for name in board_states:
    filename=board_picture_folder+"/"+name
    board_string=board_states[name]
    
    state=Board(board_string)
    print(filename,board_string)
    image=imread(filename)

    # these 5 lines are specific to your image
    im3=straighten_image(image,corners)

    squares=get_board_squares_from_image(im3,
                                     state.shape,
                                     middle_pixels=20)  # <=== check this
    


    if not os.path.exists(square_images_folder):
        print(f"Making folder {square_images_folder}")
        os.mkdir(square_images_folder)
    
    
    nr,nc=state.shape
    saveit=True

    figure()
    plot_count=0
    for r in range(nr):
        for c in range(nc):
    
            subplot(nr,nc,plot_count+1)
            imshow(squares[plot_count])
    
            shape=squares[plot_count].shape
            piece=state.board[plot_count]
            
            title(f"Piece {piece}")
            if c==0:
                ylabel(shape[0])
    
            if r==nr-1:
                xlabel(shape[1])
            gca().set_xticklabels([])
            gca().set_yticklabels([])
    
    
            if saveit:
                piece_folder=f"{square_images_folder}/piece_{piece}"
                if not os.path.exists(piece_folder):
                    print(f"Making folder {piece_folder}")
                    os.mkdir(piece_folder)
                
                fname=f"{piece_folder}/square{count}_{piece}.jpg"
                print(fname)
                imsave(fname,squares[plot_count])
            
            
            plot_count+=1  
            count+=1
# Out:
# images/2024-11-21 - training board images/test10.jpg 0000/0000/0000/0000
# images/2024-11-21 - training squares/piece_0/square0_0.jpg
# images/2024-11-21 - training squares/piece_0/square1_0.jpg
# images/2024-11-21 - training squares/piece_0/square2_0.jpg
# images/2024-11-21 - training squares/piece_0/square3_0.jpg
# images/2024-11-21 - training squares/piece_0/square4_0.jpg
# images/2024-11-21 - training squares/piece_0/square5_0.jpg
# images/2024-11-21 - training squares/piece_0/square6_0.jpg
# images/2024-11-21 - training squares/piece_0/square7_0.jpg
# images/2024-11-21 - training squares/piece_0/square8_0.jpg
# images/2024-11-21 - training squares/piece_0/square9_0.jpg
# images/2024-11-21 - training squares/piece_0/square10_0.jpg
# images/2024-11-21 - training squares/piece_0/square11_0.jpg
# images/2024-11-21 - training squares/piece_0/square12_0.jpg
# images/2024-11-21 - training squares/piece_0/square13_0.jpg
# images/2024-11-21 - training squares/piece_0/square14_0.jpg
# images/2024-11-21 - training squares/piece_0/square15_0.jpg
# images/2024-11-21 - training board images/test6.jpg 1111/1111/1111/1111
# images/2024-11-21 - training squares/piece_1/square16_1.jpg
# images/2024-11-21 - training squares/piece_1/square17_1.jpg
# images/2024-11-21 - training squares/piece_1/square18_1.jpg
# images/2024-11-21 - training squares/piece_1/square19_1.jpg
# images/2024-11-21 - training squares/piece_1/square20_1.jpg
# images/2024-11-21 - training squares/piece_1/square21_1.jpg
# images/2024-11-21 - training squares/piece_1/square22_1.jpg
# images/2024-11-21 - training squares/piece_1/square23_1.jpg
# images/2024-11-21 - training squares/piece_1/square24_1.jpg
# images/2024-11-21 - training squares/piece_1/square25_1.jpg
# images/2024-11-21 - training squares/piece_1/square26_1.jpg
# images/2024-11-21 - training squares/piece_1/square27_1.jpg
# images/2024-11-21 - training squares/piece_1/square28_1.jpg
# images/2024-11-21 - training squares/piece_1/square29_1.jpg
# images/2024-11-21 - training squares/piece_1/square30_1.jpg
# images/2024-11-21 - training squares/piece_1/square31_1.jpg
# images/2024-11-21 - training board images/test7.jpg 1111/1111/1111/1111
# images/2024-11-21 - training squares/piece_1/square32_1.jpg
# images/2024-11-21 - training squares/piece_1/square33_1.jpg
# images/2024-11-21 - training squares/piece_1/square34_1.jpg
# images/2024-11-21 - training squares/piece_1/square35_1.jpg
# images/2024-11-21 - training squares/piece_1/square36_1.jpg
# images/2024-11-21 - training squares/piece_1/square37_1.jpg
# images/2024-11-21 - training squares/piece_1/square38_1.jpg
# images/2024-11-21 - training squares/piece_1/square39_1.jpg
# images/2024-11-21 - training squares/piece_1/square40_1.jpg
# images/2024-11-21 - training squares/piece_1/square41_1.jpg
# images/2024-11-21 - training squares/piece_1/square42_1.jpg
# images/2024-11-21 - training squares/piece_1/square43_1.jpg
# images/2024-11-21 - training squares/piece_1/square44_1.jpg
# images/2024-11-21 - training squares/piece_1/square45_1.jpg
# images/2024-11-21 - training squares/piece_1/square46_1.jpg
# images/2024-11-21 - training squares/piece_1/square47_1.jpg
# images/2024-11-21 - training board images/test5.jpg 1111/1111/1111/1111
# images/2024-11-21 - training squares/piece_1/square48_1.jpg
# images/2024-11-21 - training squares/piece_1/square49_1.jpg
# images/2024-11-21 - training squares/piece_1/square50_1.jpg
# images/2024-11-21 - training squares/piece_1/square51_1.jpg
# images/2024-11-21 - training squares/piece_1/square52_1.jpg
# images/2024-11-21 - training squares/piece_1/square53_1.jpg
# images/2024-11-21 - training squares/piece_1/square54_1.jpg
# images/2024-11-21 - training squares/piece_1/square55_1.jpg
# images/2024-11-21 - training squares/piece_1/square56_1.jpg
# images/2024-11-21 - training squares/piece_1/square57_1.jpg
# images/2024-11-21 - training squares/piece_1/square58_1.jpg
# images/2024-11-21 - training squares/piece_1/square59_1.jpg
# images/2024-11-21 - training squares/piece_1/square60_1.jpg
# images/2024-11-21 - training squares/piece_1/square61_1.jpg
# images/2024-11-21 - training squares/piece_1/square62_1.jpg
# images/2024-11-21 - training squares/piece_1/square63_1.jpg
# images/2024-11-21 - training board images/test4.jpg 0000/0000/0000/0000
# images/2024-11-21 - training squares/piece_0/square64_0.jpg
# images/2024-11-21 - training squares/piece_0/square65_0.jpg
# images/2024-11-21 - training squares/piece_0/square66_0.jpg
# images/2024-11-21 - training squares/piece_0/square67_0.jpg
# images/2024-11-21 - training squares/piece_0/square68_0.jpg
# images/2024-11-21 - training squares/piece_0/square69_0.jpg
# images/2024-11-21 - training squares/piece_0/square70_0.jpg
# images/2024-11-21 - training squares/piece_0/square71_0.jpg
# images/2024-11-21 - training squares/piece_0/square72_0.jpg
# images/2024-11-21 - training squares/piece_0/square73_0.jpg
# images/2024-11-21 - training squares/piece_0/square74_0.jpg
# images/2024-11-21 - training squares/piece_0/square75_0.jpg
# images/2024-11-21 - training squares/piece_0/square76_0.jpg
# images/2024-11-21 - training squares/piece_0/square77_0.jpg
# images/2024-11-21 - training squares/piece_0/square78_0.jpg
# images/2024-11-21 - training squares/piece_0/square79_0.jpg
# images/2024-11-21 - training board images/test0.jpg 2222/2222/2222/2222
# images/2024-11-21 - training squares/piece_2/square80_2.jpg
# images/2024-11-21 - training squares/piece_2/square81_2.jpg
# images/2024-11-21 - training squares/piece_2/square82_2.jpg
# images/2024-11-21 - training squares/piece_2/square83_2.jpg
# images/2024-11-21 - training squares/piece_2/square84_2.jpg
# images/2024-11-21 - training squares/piece_2/square85_2.jpg
# images/2024-11-21 - training squares/piece_2/square86_2.jpg
# images/2024-11-21 - training squares/piece_2/square87_2.jpg
# images/2024-11-21 - training squares/piece_2/square88_2.jpg
# images/2024-11-21 - training squares/piece_2/square89_2.jpg
# images/2024-11-21 - training squares/piece_2/square90_2.jpg
# images/2024-11-21 - training squares/piece_2/square91_2.jpg
# images/2024-11-21 - training squares/piece_2/square92_2.jpg
# images/2024-11-21 - training squares/piece_2/square93_2.jpg
# images/2024-11-21 - training squares/piece_2/square94_2.jpg
# images/2024-11-21 - training squares/piece_2/square95_2.jpg
# images/2024-11-21 - training board images/test1.jpg 2222/2222/2222/2222
# images/2024-11-21 - training squares/piece_2/square96_2.jpg
# images/2024-11-21 - training squares/piece_2/square97_2.jpg
# images/2024-11-21 - training squares/piece_2/square98_2.jpg
# images/2024-11-21 - training squares/piece_2/square99_2.jpg
# images/2024-11-21 - training squares/piece_2/square100_2.jpg
# images/2024-11-21 - training squares/piece_2/square101_2.jpg
# images/2024-11-21 - training squares/piece_2/square102_2.jpg
# images/2024-11-21 - training squares/piece_2/square103_2.jpg
# images/2024-11-21 - training squares/piece_2/square104_2.jpg
# images/2024-11-21 - training squares/piece_2/square105_2.jpg
# images/2024-11-21 - training squares/piece_2/square106_2.jpg
# images/2024-11-21 - training squares/piece_2/square107_2.jpg
# images/2024-11-21 - training squares/piece_2/square108_2.jpg
# images/2024-11-21 - training squares/piece_2/square109_2.jpg
# images/2024-11-21 - training squares/piece_2/square110_2.jpg
# images/2024-11-21 - training squares/piece_2/square111_2.jpg
# images/2024-11-21 - training board images/test3.jpg 0202/2020/0202/0202
# images/2024-11-21 - training squares/piece_0/square112_0.jpg
# images/2024-11-21 - training squares/piece_2/square113_2.jpg
# images/2024-11-21 - training squares/piece_0/square114_0.jpg
# images/2024-11-21 - training squares/piece_2/square115_2.jpg
# images/2024-11-21 - training squares/piece_2/square116_2.jpg
# images/2024-11-21 - training squares/piece_0/square117_0.jpg
# images/2024-11-21 - training squares/piece_2/square118_2.jpg
# images/2024-11-21 - training squares/piece_0/square119_0.jpg
# images/2024-11-21 - training squares/piece_0/square120_0.jpg
# images/2024-11-21 - training squares/piece_2/square121_2.jpg
# images/2024-11-21 - training squares/piece_0/square122_0.jpg
# images/2024-11-21 - training squares/piece_2/square123_2.jpg
# images/2024-11-21 - training squares/piece_0/square124_0.jpg
# images/2024-11-21 - training squares/piece_2/square125_2.jpg
# images/2024-11-21 - training squares/piece_0/square126_0.jpg
# images/2024-11-21 - training squares/piece_2/square127_2.jpg
# images/2024-11-21 - training board images/test2.jpg 2222/2222/2222/2222
# images/2024-11-21 - training squares/piece_2/square128_2.jpg
# images/2024-11-21 - training squares/piece_2/square129_2.jpg
# images/2024-11-21 - training squares/piece_2/square130_2.jpg
# images/2024-11-21 - training squares/piece_2/square131_2.jpg
# images/2024-11-21 - training squares/piece_2/square132_2.jpg
# images/2024-11-21 - training squares/piece_2/square133_2.jpg
# images/2024-11-21 - training squares/piece_2/square134_2.jpg
# images/2024-11-21 - training squares/piece_2/square135_2.jpg
# images/2024-11-21 - training squares/piece_2/square136_2.jpg
# images/2024-11-21 - training squares/piece_2/square137_2.jpg
# images/2024-11-21 - training squares/piece_2/square138_2.jpg
# images/2024-11-21 - training squares/piece_2/square139_2.jpg
# images/2024-11-21 - training squares/piece_2/square140_2.jpg
# images/2024-11-21 - training squares/piece_2/square141_2.jpg
# images/2024-11-21 - training squares/piece_2/square142_2.jpg
# images/2024-11-21 - training squares/piece_2/square143_2.jpg
# images/2024-11-21 - training board images/test8.jpg 1101/1011/0000/1111
# images/2024-11-21 - training squares/piece_1/square144_1.jpg
# images/2024-11-21 - training squares/piece_1/square145_1.jpg
# images/2024-11-21 - training squares/piece_0/square146_0.jpg
# images/2024-11-21 - training squares/piece_1/square147_1.jpg
# images/2024-11-21 - training squares/piece_1/square148_1.jpg
# images/2024-11-21 - training squares/piece_0/square149_0.jpg
# images/2024-11-21 - training squares/piece_1/square150_1.jpg
# images/2024-11-21 - training squares/piece_1/square151_1.jpg
# images/2024-11-21 - training squares/piece_0/square152_0.jpg
# images/2024-11-21 - training squares/piece_0/square153_0.jpg
# images/2024-11-21 - training squares/piece_0/square154_0.jpg
# images/2024-11-21 - training squares/piece_0/square155_0.jpg
# images/2024-11-21 - training squares/piece_1/square156_1.jpg
# images/2024-11-21 - training squares/piece_1/square157_1.jpg
# images/2024-11-21 - training squares/piece_1/square158_1.jpg
# images/2024-11-21 - training squares/piece_1/square159_1.jpg
